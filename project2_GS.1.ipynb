# %% [markdown]
# <a href="https://colab.research.google.com/github/deepw98/project2/blob/main/project2_GS.1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !cp -r /content/drive/MyDrive/fire_detection_few_shot /content/fire_detection_few_shot

# %%
import tensorflow as tf
import os
import cv2
import numpy as np
from sklearn.model_selection import train_test_split  # For creating validation split if needed
from tensorflow.keras.layers import RandomRotation  # Im

# %%
import cv2
import numpy as np
import os

def load_and_preprocess_image(image_path, target_size=(224, 224), augment=False):

    # Ensuring image_path is a valid string
    if not isinstance(image_path, str):
        raise ValueError(f"Invalid image path type: {type(image_path)}. Expected a string.")

    if not os.path.exists(image_path):
        raise FileNotFoundError(f"Image not found at: {image_path}")

    img = cv2.imread(image_path)
    if img is None:
        raise ValueError(f"Failed to load image at: {image_path}")

    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

    # Getting original dimensions
    original_height, original_width = img.shape[:2]
    target_height, target_width = target_size

    # Computing the scale to maintain aspect ratio
    scale = min(target_width / original_width, target_height / original_height)
    new_width = int(original_width * scale)
    new_height = int(original_height * scale)

    # Resizing while keeping aspect ratio
    img_resized = cv2.resize(img, (new_width, new_height), interpolation=cv2.INTER_AREA)

    # Creating a black canvas and center the resized image
    img_padded = np.zeros((target_height, target_width, 3), dtype=np.uint8)
    pad_top = (target_height - new_height) // 2
    pad_left = (target_width - new_width) // 2
    img_padded[pad_top:pad_top+new_height, pad_left:pad_left+new_width] = img_resized

    # Normalizing
    img_padded = img_padded.astype('float32') / 255.0

    return img_padded

# %%
def create_image_pairs(fire_dir, non_fire_dir, target_size=(224, 224), augment_pairs=False):

    if isinstance(fire_dir, list):
        fire_dir = os.path.dirname(fire_dir[0])
    if isinstance(non_fire_dir, list):
        non_fire_dir = os.path.dirname(non_fire_dir[0])

    # checking directories
    if not os.path.exists(fire_dir) or not os.path.exists(non_fire_dir):
        raise ValueError(f"Invalid directory paths:\nFire: {fire_dir}\nNon-Fire: {non_fire_dir}")

    # Getting image file paths
    fire_images = [os.path.join(fire_dir, f) for f in os.listdir(fire_dir) if os.path.isfile(os.path.join(fire_dir, f))]
    non_fire_images = [os.path.join(non_fire_dir, f) for f in os.listdir(non_fire_dir) if os.path.isfile(os.path.join(non_fire_dir, f))]

    if not fire_images or not non_fire_images:
        raise ValueError("Error: One of the classes has no images. Check dataset paths.")

    pair_images = []
    pair_labels = []

    # Positive Pairs (Fire-Fire and Non-Fire-Non-Fire)
    min_len = min(len(fire_images), len(non_fire_images))  # To balance positive pairs
    for i in range(min_len):
        # Fire - Fire Pair
        img1_fire = load_and_preprocess_image(fire_images[i], target_size, augment=augment_pairs)
        img2_fire = load_and_preprocess_image(fire_images[(i + 1) % len(fire_images)], target_size, augment=augment_pairs)
        pair_images.append(np.array([img1_fire, img2_fire]))
        pair_labels.append(1)  # Similar (Fire-Fire)

        # Non-Fire - Non-Fire Pair
        img1_non_fire = load_and_preprocess_image(non_fire_images[i], target_size, augment=augment_pairs)
        img2_non_fire = load_and_preprocess_image(non_fire_images[(i + 1) % len(non_fire_images)], target_size, augment=augment_pairs)
        pair_images.append(np.array([img1_non_fire, img2_non_fire]))
        pair_labels.append(1)  # Similar (Non-Fire-Non-Fire)

    # Negative Pairs (Fire-Non-Fire)
    for i in range(min_len * 2):  # Create more negative pairs
        img_fire = load_and_preprocess_image(fire_images[i % len(fire_images)], target_size, augment=augment_pairs)
        img_non_fire = load_and_preprocess_image(non_fire_images[i % len(non_fire_images)], target_size, augment=augment_pairs)
        pair_images.append(np.array([img_fire, img_non_fire]))
        pair_labels.append(0)  # Dissimilar (Fire-Non-Fire)

    return np.array(pair_images), np.array(pair_labels)  # Return as NumPy arrays

# %%
def prepare_data_for_training(train_fire_dir, train_non_fire_dir,
                              test_fire_dir, test_non_fire_dir,
                              target_size=(224, 224), augment_train_pairs=True):


    train_pairs, train_labels = create_image_pairs(
        train_fire_dir, train_non_fire_dir, target_size=target_size, augment_pairs=augment_train_pairs
    )
    print("Number of training pairs:", len(train_pairs))

    test_pairs, test_labels = create_image_pairs(
        test_fire_dir, test_non_fire_dir, target_size=target_size, augment_pairs=False  # No augmentation for test
    )

    # Convert lists to NumPy arrays for TensorFlow
    train_pairs = np.array(train_pairs)
    train_labels = np.array(train_labels)
    test_pairs = np.array(test_pairs)
    test_labels = np.array(test_labels)

  #  image_paths = {'train': train_image_paths, 'test': test_image_paths}

    print(f"Number of Training Pairs: {len(train_pairs)}")
    print(f"Number of Testing Pairs: {len(test_pairs)}")

    return train_pairs, train_labels, test_pairs, test_labels

# Directory paths
train_fire_dir = '/content/fire_detection_few_shot/train/Fire'
train_non_fire_dir = '/content/fire_detection_few_shot/train/No_Fire'
test_fire_dir = '/content/fire_detection_few_shot/test/Fire'
test_non_fire_dir = '/content/fire_detection_few_shot/test/No_Fire'

# --- Preparing the data ---
target_image_size = (224, 224)

train_pair_data, train_pair_labels, test_pair_data, test_pair_labels = prepare_data_for_training(
    train_fire_dir, train_non_fire_dir, test_fire_dir, test_non_fire_dir, target_size=target_image_size, augment_train_pairs=True
)

print("\nData Preprocessing Complete. Data is ready for Siamese Network training.")
print("Example of a training pair shape:", train_pair_data[0].shape)
print("Example of a training pair label:", train_pair_labels[0])
# Out:
# Number of training pairs: 568
# Number of Training Pairs: 568
# Number of Testing Pairs: 40
#
# Data Preprocessing Complete. Data is ready for Siamese Network training.
# Example of a training pair shape: (2, 224, 224, 3)
# Example of a training pair label: 1

# %%
import tensorflow as tf
from tensorflow.keras.applications import EfficientNetB0
from tensorflow.keras.layers import Input, Layer, GlobalAveragePooling2D, Dense, concatenate
from tensorflow.keras.models import Model
from tensorflow.keras import backend as K

import tensorflow as tf
from tensorflow.keras.layers import Layer, concatenate
from tensorflow.keras import backend as K

class DistanceLayer(Layer):
    def __init__(self, **kwargs):
        super(DistanceLayer, self).__init__(**kwargs)

    def call(self, embeddings):
        embedding_1, embedding_2 = embeddings

        # Ensuring correct tensor shapes
        embedding_1 = tf.reshape(embedding_1, (-1, 1280))
        embedding_2 = tf.reshape(embedding_2, (-1, 1280))

        # Euclidean Distance (Squared L2 Norm)
        euclidean_distance = tf.reduce_sum(tf.square(embedding_1 - embedding_2), axis=-1, keepdims=True)

        # Cosine Similarity
        x = K.l2_normalize(embedding_1, axis=-1)
        y = K.l2_normalize(embedding_2, axis=-1)
        cosine_similarity = -tf.reduce_sum(x * y, axis=-1, keepdims=True)

        # Manhattan Distance (L1 Norm)
        manhattan_distance = tf.reduce_sum(tf.abs(embedding_1 - embedding_2), axis=-1, keepdims=True)

        return concatenate([euclidean_distance, cosine_similarity, manhattan_distance], axis=-1)

    def get_config(self):
        return super().get_config()

# %%
def build_efficientnet_encoder(input_shape):

    efficientnet = EfficientNetB0(include_top=False, weights='imagenet', input_shape=input_shape)

    input_tensor = Input(shape=input_shape)
    embedding = efficientnet(input_tensor)
    embedding = GlobalAveragePooling2D()(embedding) # Getting embedding vector after GAP

    return Model(input_tensor, embedding)

# %%
import tensorflow as tf
import numpy as np
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.models import Model

# Register DistanceLayer
from tensorflow.keras.utils import get_custom_objects
get_custom_objects().update({"DistanceLayer": DistanceLayer})

def build_siamese_model(input_shape, distance_weights=None):

    encoder = build_efficientnet_encoder(input_shape)
    print("Output shape of encoder model:", encoder.output_shape)

    # Input layers for each image in the pair
    input_image_1 = Input(shape=input_shape, name="image_1_input")
    input_image_2 = Input(shape=input_shape, name="image_2_input")

    # Embeddings for each image
    embedding_1 = encoder(input_image_1)
    embedding_2 = encoder(input_image_2)

    # Distance layer
    distance_vector = DistanceLayer()([embedding_1, embedding_2])

    # Weighted Distance Combination (Ensemble)
    if distance_weights is None:
        distance_weights = [0.33, 0.33, 0.34]  # Default equal weights
    distance_weights = np.array(distance_weights).reshape(-1, 1)  # Ensuring correct shape

    weighted_distance = Dense(1, activation='linear', use_bias=False,
                              kernel_initializer=tf.keras.initializers.Constant(value=distance_weights))(distance_vector)

    # Output is the weighted distance
    siamese_output = weighted_distance

    return Model(inputs=[input_image_1, input_image_2], outputs=siamese_output)

# %%
input_shape = (224, 224, 3)
siamese_model = build_siamese_model(input_shape)

# Visualizing the model architecture
tf.keras.utils.plot_model(siamese_model, to_file='siamese_model_architecture.png', show_shapes=True, show_layer_names=True, dpi=60)
print("Siamese Model Architecture visualized and saved as 'siamese_model_architecture.png'")

siamese_model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb0_notop.h5
# 16705208/16705208 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Output shape of encoder model: (None, 1280)
# Siamese Model Architecture visualized and saved as 'siamese_model_architecture.png'
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ image_1_input             │ (None, 224, 224, 3)    │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ image_2_input             │ (None, 224, 224, 3)    │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ functional (Functional)   │ (None, 1280)           │      4,049,571 │ image_1_input[0][0],   │
# │                           │                        │                │ image_2_input[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ distance_layer            │ (None, 3)              │              0 │ functional[0][0],      │
# │ (DistanceLayer)           │                        │                │ functional[1][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense (Dense)             │ (None, 1)              │              3 │ distance_layer[0][0]   │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 4,049,574 (15.45 MB)
#  Trainable params: 4,007,551 (15.29 MB)
#  Non-trainable params: 42,023 (164.16 KB)

# %%
import tensorflow as tf

def contrastive_loss(y_true, distance, margin=1.0):

    # Cast y_true to float32 to ensure it's compatible with TensorFlow operations
    y_true = tf.cast(y_true, tf.float32)

    # Loss for similar pairs (y_true == 1)
    square_pred = tf.square(distance)
    margin_square = tf.square(tf.maximum(0.0, margin - distance)) # max(0, margin - distance)^2
    loss_similar = y_true * square_pred  # If y_true == 1, apply square_pred loss

    # Loss for dissimilar pairs (y_true == 0)
    loss_dissimilar = (1 - y_true) * margin_square # If y_true == 0, apply margin_square loss


    loss = tf.reduce_mean(loss_similar + loss_dissimilar) # Average loss over all pairs in the batch
    return loss

# %%
import tensorflow as tf
from tensorflow.keras.optimizers import Adam

input_shape = (224, 224, 3)
siamese_model = build_siamese_model(input_shape)

# Compiling the Siamese Model
optimizer = Adam(learning_rate=0.0001)

siamese_model.compile(optimizer=optimizer,
                      loss=contrastive_loss) # Using contrastive_loss function

print("Siamese Model Compiled!")
# Out:
# Output shape of encoder model: (None, 1280)
# Siamese Model Compiled!

# %%
import os

def get_image_paths(folder):
    """
    Get all image file paths from a given directory.
    """
    image_extensions = (".jpg", ".jpeg", ".png")
    return [os.path.join(folder, f) for f in os.listdir(folder) if f.endswith(image_extensions)]

# Getting image paths
fire_images = get_image_paths("/content/fire_detection_few_shot/train/Fire")
no_fire_images = get_image_paths("/content/fire_detection_few_shot/train/No_Fire")

print(f"Found {len(fire_images)} fire images and {len(no_fire_images)} no-fire images.")
# Out:
# Found 152 fire images and 142 no-fire images.

# %%
import numpy as np
import tensorflow as tf

def create_few_shot_task(fire_images, no_fire_images, N=2, K=5, Q=1):

    fire_samples = np.random.choice(fire_images, K + Q, replace=False)
    no_fire_samples = np.random.choice(no_fire_images, K + Q, replace=False)

    # Create support and query sets
    support_set = np.concatenate([fire_samples[:K], no_fire_samples[:K]])
    query_set = np.concatenate([fire_samples[K:], no_fire_samples[K:]])
    labels = np.array([1] * Q + [0] * Q)  # 1 for fire, 0 for no-fire

    return support_set, query_set, labels

# %%
def episodic_training(model, fire_images, no_fire_images, epochs=1000, K=5, Q=1):
    """Performs episodic training for few-shot learning."""
    for epoch in range(epochs):
        print(f"Epoch {epoch+1}/{epochs}")

        try:
            # Sampling K examples for the support set
            fire_sample = np.random.choice(fire_images, K, replace=False)
            no_fire_sample = np.random.choice(no_fire_images, K, replace=False)
        except ValueError:
            print("Not enough images for the chosen K value.")
            continue

        # Loading and preprocessing images
        fire_batch = np.array([load_and_preprocess_image(img) for img in fire_sample])
        no_fire_batch = np.array([load_and_preprocess_image(img) for img in no_fire_sample])

        # Create pairs (input_1, input_2) and labels
        pairs = []
        labels = []

        # Similar pairs (fire-fire, no-fire-no-fire)
        for i in range(K):
            pairs.append([fire_batch[i], fire_batch[(i + 1) % K]])  # Fire-Fire
            labels.append(1)
            pairs.append([no_fire_batch[i], no_fire_batch[(i + 1) % K]])  # NoFire-NoFire
            labels.append(1)

        # Dissimilar pairs (fire-no-fire)
        for i in range(K):
            pairs.append([fire_batch[i], no_fire_batch[i]])  # Fire-NoFire
            labels.append(0)

        # Convert pairs to numpy arrays
        input_1 = np.array([pair[0] for pair in pairs])
        input_2 = np.array([pair[1] for pair in pairs])
        labels = np.array(labels)

        # Train step
        loss = model.train_on_batch([input_1, input_2], labels)
        print(f"Loss: {loss}")


    print("Training complete.")

# %%
from tensorflow.keras.optimizers import Adam
optimizer = Adam(learning_rate=0.001)
siamese_model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])

# %%
# Train the model with few-shot learning
episodic_training(siamese_model, fire_images, no_fire_images, epochs=1000, K=5, Q=1)
# Out:
# Epoch 1/1000
# Loss: [array(5.314128, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 2/1000
# Loss: [array(5.314128, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 3/1000
# Loss: [array(5.3141284, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 4/1000
# Loss: [array(5.314128, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 5/1000
# Loss: [array(5.314128, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 6/1000
# Loss: [array(5.314128, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 7/1000
# Loss: [array(5.3141284, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 8/1000
# Loss: [array(5.314128, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 9/1000
# Loss: [array(5.314128, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 10/1000
# Loss: [array(5.314128, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 11/1000
# Loss: [array(5.314128, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 12/1000
# Loss: [array(5.314128, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 13/1000
# Loss: [array(5.3141284, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 14/1000
# Loss: [array(5.3141284, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 15/1000
# Loss: [array(5.314128, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 16/1000
# Loss: [array(5.314128, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 17/1000
# Loss: [array(5.314128, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 18/1000
# Loss: [array(5.314128, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 19/1000
# Loss: [array(5.314128, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 20/1000
# Loss: [array(5.314128, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 21/1000
# Loss: [array(5.314128, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 22/1000
# Loss: [array(5.314128, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 23/1000
# Loss: [array(5.314128, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 24/1000
# Loss: [array(5.314128, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 25/1000
# Loss: [array(5.314128, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 26/1000
# Loss: [array(5.3141284, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 27/1000
# Loss: [array(5.3141284, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 28/1000
# Loss: [array(5.3141284, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 29/1000
# Loss: [array(5.3141284, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 30/1000
# Loss: [array(5.314128, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 31/1000
# Loss: [array(5.314128, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 32/1000
# Loss: [array(5.314128, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 33/1000
# Loss: [array(5.314128, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 34/1000
# Loss: [array(5.314128, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 35/1000
# Loss: [array(5.314128, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 36/1000
# Loss: [array(5.314128, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 37/1000
# Loss: [array(5.314128, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 38/1000
# Loss: [array(5.314128, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 39/1000
# Loss: [array(5.314128, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 40/1000
# Loss: [array(5.314128, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 41/1000
# Loss: [array(5.314128, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 42/1000
# Loss: [array(5.314128, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 43/1000
# Loss: [array(5.314128, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 44/1000
# Loss: [array(5.314128, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 45/1000
# Loss: [array(5.314128, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 46/1000
# Loss: [array(5.314128, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 47/1000
# Loss: [array(5.314128, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 48/1000
# Loss: [array(5.314128, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 49/1000
# Loss: [array(5.314128, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 50/1000
# Loss: [array(5.314128, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 51/1000
# Loss: [array(5.314128, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 52/1000
# Loss: [array(5.3141284, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 53/1000
# Loss: [array(5.3141284, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 54/1000
# Loss: [array(5.3141284, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 55/1000
# Loss: [array(5.3141284, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 56/1000
# Loss: [array(5.3141284, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 57/1000
# Loss: [array(5.3141284, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 58/1000
# Loss: [array(5.3141284, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 59/1000
# Loss: [array(5.314128, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 60/1000
# Loss: [array(5.314128, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 61/1000
# Loss: [array(5.314128, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 62/1000
# Loss: [array(5.314128, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 63/1000
# Loss: [array(5.314128, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 64/1000
# Loss: [array(5.314128, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 65/1000
# Loss: [array(5.314128, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 66/1000
# Loss: [array(5.314128, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 67/1000
# Loss: [array(5.314128, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 68/1000
# Loss: [array(5.314128, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 69/1000
# Loss: [array(5.314128, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 70/1000
# Loss: [array(5.314128, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 71/1000
# Loss: [array(5.314128, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 72/1000
# Loss: [array(5.314128, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 73/1000
# Loss: [array(5.314128, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 74/1000
# Loss: [array(5.314128, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 75/1000
# Loss: [array(5.314128, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 76/1000
# Loss: [array(5.314128, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 77/1000
# Loss: [array(5.314128, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 78/1000
# Loss: [array(5.314128, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 79/1000
# Loss: [array(5.314128, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 80/1000
# Loss: [array(5.314128, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 81/1000
# Loss: [array(5.314128, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 82/1000
# Loss: [array(5.314128, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 83/1000
# Loss: [array(5.314128, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 84/1000
# Loss: [array(5.314128, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 85/1000
# Loss: [array(5.314128, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 86/1000
# Loss: [array(5.314128, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 87/1000
# Loss: [array(5.314128, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 88/1000
# Loss: [array(5.314128, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 89/1000
# Loss: [array(5.314128, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 90/1000
# Loss: [array(5.314128, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 91/1000
# Loss: [array(5.314128, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 92/1000
# Loss: [array(5.314128, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 93/1000
# Loss: [array(5.314128, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 94/1000
# Loss: [array(5.314128, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 95/1000
# Loss: [array(5.314128, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 96/1000
# Loss: [array(5.314128, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 97/1000
# Loss: [array(5.314128, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 98/1000
# Loss: [array(5.314128, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 99/1000
# Loss: [array(5.314128, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 100/1000
# Loss: [array(5.314128, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 101/1000
# Loss: [array(5.314128, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 102/1000
# Loss: [array(5.314128, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 103/1000
# Loss: [array(5.3141284, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 104/1000
# Loss: [array(5.3141284, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 105/1000
# Loss: [array(5.3141284, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 106/1000
# Loss: [array(5.3141284, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 107/1000
# Loss: [array(5.3141284, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 108/1000
# Loss: [array(5.3141284, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 109/1000
# Loss: [array(5.3141284, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 110/1000
# Loss: [array(5.3141284, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 111/1000
# Loss: [array(5.3141284, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 112/1000
# Loss: [array(5.3141284, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 113/1000
# Loss: [array(5.3141284, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 114/1000
# Loss: [array(5.3141284, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 115/1000
# Loss: [array(5.3141284, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 116/1000
# Loss: [array(5.3141284, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 117/1000
# Loss: [array(5.3141284, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 118/1000
# Loss: [array(5.314128, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 119/1000
# Loss: [array(5.314128, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 120/1000
# Loss: [array(5.314128, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 121/1000
# Loss: [array(5.314128, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 122/1000
# Loss: [array(5.314128, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 123/1000
# Loss: [array(5.314128, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 124/1000
# Loss: [array(5.314128, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 125/1000
# Loss: [array(5.314128, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 126/1000
# Loss: [array(5.314128, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 127/1000
# Loss: [array(5.314128, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 128/1000
# Loss: [array(5.314128, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 129/1000
# Loss: [array(5.314128, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 130/1000
# Loss: [array(5.314128, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 131/1000
# Loss: [array(5.314128, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 132/1000
# Loss: [array(5.314128, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 133/1000
# Loss: [array(5.314128, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 134/1000
# Loss: [array(5.314128, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 135/1000
# Loss: [array(5.314128, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 136/1000
# Loss: [array(5.314128, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 137/1000
# Loss: [array(5.314128, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 138/1000
# Loss: [array(5.314128, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 139/1000
# Loss: [array(5.314128, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 140/1000
# Loss: [array(5.314128, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 141/1000
# Loss: [array(5.314128, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 142/1000
# Loss: [array(5.314128, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 143/1000
# Loss: [array(5.314128, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 144/1000
# Loss: [array(5.314128, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 145/1000
# Loss: [array(5.314128, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 146/1000
# Loss: [array(5.314128, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 147/1000
# Loss: [array(5.314128, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 148/1000
# Loss: [array(5.314128, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 149/1000
# Loss: [array(5.314128, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 150/1000
# Loss: [array(5.314128, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 151/1000
# Loss: [array(5.314128, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 152/1000
# Loss: [array(5.314128, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 153/1000
# Loss: [array(5.314128, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 154/1000
# Loss: [array(5.314128, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 155/1000
# Loss: [array(5.314128, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 156/1000
# Loss: [array(5.314128, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 157/1000
# Loss: [array(5.314128, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 158/1000
# Loss: [array(5.314128, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 159/1000
# Loss: [array(5.314128, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 160/1000
# Loss: [array(5.314128, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 161/1000
# Loss: [array(5.314128, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 162/1000
# Loss: [array(5.314128, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 163/1000
# Loss: [array(5.314128, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 164/1000
# Loss: [array(5.314128, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 165/1000
# Loss: [array(5.314128, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 166/1000
# Loss: [array(5.314128, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 167/1000
# Loss: [array(5.314128, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 168/1000
# Loss: [array(5.314128, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 169/1000
# Loss: [array(5.314128, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 170/1000
# Loss: [array(5.314128, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 171/1000
# Loss: [array(5.314128, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 172/1000
# Loss: [array(5.314128, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 173/1000
# Loss: [array(5.314128, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 174/1000
# Loss: [array(5.314128, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 175/1000
# Loss: [array(5.314128, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 176/1000
# Loss: [array(5.314128, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 177/1000
# Loss: [array(5.314128, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 178/1000
# Loss: [array(5.314128, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 179/1000
# Loss: [array(5.314128, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 180/1000
# Loss: [array(5.314128, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 181/1000
# Loss: [array(5.314128, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 182/1000
# Loss: [array(5.314128, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 183/1000
# Loss: [array(5.314128, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 184/1000
# Loss: [array(5.314128, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 185/1000
# Loss: [array(5.314128, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 186/1000
# Loss: [array(5.314128, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 187/1000
# Loss: [array(5.314128, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 188/1000
# Loss: [array(5.314128, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 189/1000
# Loss: [array(5.314128, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 190/1000
# Loss: [array(5.314128, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 191/1000
# Loss: [array(5.314128, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 192/1000
# Loss: [array(5.314128, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 193/1000
# Loss: [array(5.314128, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 194/1000
# Loss: [array(5.314128, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 195/1000
# Loss: [array(5.314128, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 196/1000
# Loss: [array(5.314128, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 197/1000
# Loss: [array(5.314128, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 198/1000
# Loss: [array(5.314128, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 199/1000
# Loss: [array(5.314128, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 200/1000
# Loss: [array(5.314128, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 201/1000
# Loss: [array(5.314128, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 202/1000
# Loss: [array(5.314128, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 203/1000
# Loss: [array(5.314128, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 204/1000
# Loss: [array(5.314128, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 205/1000
# Loss: [array(5.314128, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 206/1000
# Loss: [array(5.3141284, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 207/1000
# Loss: [array(5.3141284, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 208/1000
# Loss: [array(5.314129, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 209/1000
# Loss: [array(5.3141294, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 210/1000
# Loss: [array(5.3141294, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 211/1000
# Loss: [array(5.31413, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 212/1000
# Loss: [array(5.31413, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 213/1000
# Loss: [array(5.3141303, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 214/1000
# Loss: [array(5.314131, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 215/1000
# Loss: [array(5.314131, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 216/1000
# Loss: [array(5.3141313, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 217/1000
# Loss: [array(5.3141317, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 218/1000
# Loss: [array(5.3141317, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 219/1000
# Loss: [array(5.314132, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 220/1000
# Loss: [array(5.314132, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 221/1000
# Loss: [array(5.3141327, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 222/1000
# Loss: [array(5.3141327, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 223/1000
# Loss: [array(5.314133, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 224/1000
# Loss: [array(5.3141336, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 225/1000
# Loss: [array(5.3141336, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 226/1000
# Loss: [array(5.314134, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 227/1000
# Loss: [array(5.314134, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 228/1000
# Loss: [array(5.3141346, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 229/1000
# Loss: [array(5.3141346, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 230/1000
# Loss: [array(5.314135, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 231/1000
# Loss: [array(5.314135, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 232/1000
# Loss: [array(5.3141356, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 233/1000
# Loss: [array(5.3141356, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 234/1000
# Loss: [array(5.314136, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 235/1000
# Loss: [array(5.314136, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 236/1000
# Loss: [array(5.3141365, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 237/1000
# Loss: [array(5.3141365, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 238/1000
# Loss: [array(5.314137, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 239/1000
# Loss: [array(5.314137, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 240/1000
# Loss: [array(5.3141375, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 241/1000
# Loss: [array(5.3141375, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 242/1000
# Loss: [array(5.314138, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 243/1000
# Loss: [array(5.314138, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 244/1000
# Loss: [array(5.3141384, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 245/1000
# Loss: [array(5.3141384, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 246/1000
# Loss: [array(5.314139, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 247/1000
# Loss: [array(5.314139, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 248/1000
# Loss: [array(5.3141394, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 249/1000
# Loss: [array(5.3141394, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 250/1000
# Loss: [array(5.3141394, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 251/1000
# Loss: [array(5.31414, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 252/1000
# Loss: [array(5.31414, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 253/1000
# Loss: [array(5.3141403, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 254/1000
# Loss: [array(5.3141403, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 255/1000
# Loss: [array(5.314141, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 256/1000
# Loss: [array(5.314141, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 257/1000
# Loss: [array(5.314141, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 258/1000
# Loss: [array(5.3141413, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 259/1000
# Loss: [array(5.3141413, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 260/1000
# Loss: [array(5.3141418, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 261/1000
# Loss: [array(5.3141418, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 262/1000
# Loss: [array(5.314142, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 263/1000
# Loss: [array(5.314142, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 264/1000
# Loss: [array(5.314142, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 265/1000
# Loss: [array(5.3141427, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 266/1000
# Loss: [array(5.3141427, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 267/1000
# Loss: [array(5.314143, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 268/1000
# Loss: [array(5.314143, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 269/1000
# Loss: [array(5.314143, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 270/1000
# Loss: [array(5.3141437, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 271/1000
# Loss: [array(5.3141437, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 272/1000
# Loss: [array(5.3141437, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 273/1000
# Loss: [array(5.314144, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 274/1000
# Loss: [array(5.314144, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 275/1000
# Loss: [array(5.3141446, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 276/1000
# Loss: [array(5.3141446, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 277/1000
# Loss: [array(5.3141446, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 278/1000
# Loss: [array(5.314145, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 279/1000
# Loss: [array(5.314145, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 280/1000
# Loss: [array(5.314145, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 281/1000
# Loss: [array(5.3141456, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 282/1000
# Loss: [array(5.3141456, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 283/1000
# Loss: [array(5.3141456, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 284/1000
# Loss: [array(5.314146, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 285/1000
# Loss: [array(5.314146, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 286/1000
# Loss: [array(5.314146, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 287/1000
# Loss: [array(5.3141465, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 288/1000
# Loss: [array(5.3141465, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 289/1000
# Loss: [array(5.3141465, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 290/1000
# Loss: [array(5.314147, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 291/1000
# Loss: [array(5.314147, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 292/1000
# Loss: [array(5.314147, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 293/1000
# Loss: [array(5.3141475, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 294/1000
# Loss: [array(5.3141475, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 295/1000
# Loss: [array(5.3141475, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 296/1000
# Loss: [array(5.314148, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 297/1000
# Loss: [array(5.314148, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 298/1000
# Loss: [array(5.314148, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 299/1000
# Loss: [array(5.3141484, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 300/1000
# Loss: [array(5.3141484, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 301/1000
# Loss: [array(5.3141484, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 302/1000
# Loss: [array(5.314149, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 303/1000
# Loss: [array(5.314149, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 304/1000
# Loss: [array(5.314149, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 305/1000
# Loss: [array(5.3141494, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 306/1000
# Loss: [array(5.3141494, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 307/1000
# Loss: [array(5.3141494, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 308/1000
# Loss: [array(5.3141494, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 309/1000
# Loss: [array(5.31415, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 310/1000
# Loss: [array(5.31415, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 311/1000
# Loss: [array(5.31415, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 312/1000
# Loss: [array(5.3141503, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 313/1000
# Loss: [array(5.3141503, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 314/1000
# Loss: [array(5.3141503, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 315/1000
# Loss: [array(5.3141503, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 316/1000
# Loss: [array(5.314151, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 317/1000
# Loss: [array(5.314151, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 318/1000
# Loss: [array(5.314151, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 319/1000
# Loss: [array(5.3141513, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 320/1000
# Loss: [array(5.3141513, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 321/1000
# Loss: [array(5.3141513, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 322/1000
# Loss: [array(5.3141513, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 323/1000
# Loss: [array(5.314152, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 324/1000
# Loss: [array(5.314152, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 325/1000
# Loss: [array(5.314152, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 326/1000
# Loss: [array(5.314152, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 327/1000
# Loss: [array(5.3141522, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 328/1000
# Loss: [array(5.3141522, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 329/1000
# Loss: [array(5.3141522, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 330/1000
# Loss: [array(5.3141522, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 331/1000
# Loss: [array(5.3141527, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 332/1000
# Loss: [array(5.3141527, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 333/1000
# Loss: [array(5.3141527, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 334/1000
# Loss: [array(5.3141527, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 335/1000
# Loss: [array(5.314153, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 336/1000
# Loss: [array(5.314153, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 337/1000
# Loss: [array(5.314153, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 338/1000
# Loss: [array(5.314153, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 339/1000
# Loss: [array(5.3141537, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 340/1000
# Loss: [array(5.3141537, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 341/1000
# Loss: [array(5.3141537, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 342/1000
# Loss: [array(5.3141537, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 343/1000
# Loss: [array(5.314154, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 344/1000
# Loss: [array(5.314154, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 345/1000
# Loss: [array(5.314154, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 346/1000
# Loss: [array(5.314154, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 347/1000
# Loss: [array(5.3141546, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 348/1000
# Loss: [array(5.3141546, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 349/1000
# Loss: [array(5.3141546, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 350/1000
# Loss: [array(5.3141546, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 351/1000
# Loss: [array(5.314155, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 352/1000
# Loss: [array(5.314155, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 353/1000
# Loss: [array(5.314155, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 354/1000
# Loss: [array(5.314155, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 355/1000
# Loss: [array(5.314155, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 356/1000
# Loss: [array(5.3141556, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 357/1000
# Loss: [array(5.3141556, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 358/1000
# Loss: [array(5.3141556, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 359/1000
# Loss: [array(5.3141556, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 360/1000
# Loss: [array(5.3141556, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 361/1000
# Loss: [array(5.314156, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 362/1000
# Loss: [array(5.314156, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 363/1000
# Loss: [array(5.314156, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 364/1000
# Loss: [array(5.314156, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 365/1000
# Loss: [array(5.3141565, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 366/1000
# Loss: [array(5.3141565, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 367/1000
# Loss: [array(5.3141565, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 368/1000
# Loss: [array(5.3141565, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 369/1000
# Loss: [array(5.3141565, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 370/1000
# Loss: [array(5.314157, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 371/1000
# Loss: [array(5.314157, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 372/1000
# Loss: [array(5.314157, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 373/1000
# Loss: [array(5.314157, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 374/1000
# Loss: [array(5.314157, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 375/1000
# Loss: [array(5.3141575, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 376/1000
# Loss: [array(5.3141575, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 377/1000
# Loss: [array(5.3141575, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 378/1000
# Loss: [array(5.3141575, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 379/1000
# Loss: [array(5.3141575, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 380/1000
# Loss: [array(5.314158, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 381/1000
# Loss: [array(5.314158, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 382/1000
# Loss: [array(5.314158, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 383/1000
# Loss: [array(5.314158, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 384/1000
# Loss: [array(5.314158, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 385/1000
# Loss: [array(5.3141584, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 386/1000
# Loss: [array(5.3141584, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 387/1000
# Loss: [array(5.3141584, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 388/1000
# Loss: [array(5.3141584, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 389/1000
# Loss: [array(5.3141584, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 390/1000
# Loss: [array(5.3141584, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 391/1000
# Loss: [array(5.314159, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 392/1000
# Loss: [array(5.314159, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 393/1000
# Loss: [array(5.314159, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 394/1000
# Loss: [array(5.314159, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 395/1000
# Loss: [array(5.314159, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 396/1000
# Loss: [array(5.3141594, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 397/1000
# Loss: [array(5.3141594, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 398/1000
# Loss: [array(5.3141594, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 399/1000
# Loss: [array(5.3141594, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 400/1000
# Loss: [array(5.3141594, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 401/1000
# Loss: [array(5.3141594, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 402/1000
# Loss: [array(5.31416, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 403/1000
# Loss: [array(5.31416, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 404/1000
# Loss: [array(5.31416, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 405/1000
# Loss: [array(5.31416, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 406/1000
# Loss: [array(5.31416, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 407/1000
# Loss: [array(5.31416, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 408/1000
# Loss: [array(5.3141603, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 409/1000
# Loss: [array(5.3141603, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 410/1000
# Loss: [array(5.3141603, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 411/1000
# Loss: [array(5.3141603, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 412/1000
# Loss: [array(5.3141603, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 413/1000
# Loss: [array(5.3141603, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 414/1000
# Loss: [array(5.31416, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 415/1000
# Loss: [array(5.31416, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 416/1000
# Loss: [array(5.3141594, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 417/1000
# Loss: [array(5.3141594, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 418/1000
# Loss: [array(5.314159, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 419/1000
# Loss: [array(5.314159, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 420/1000
# Loss: [array(5.3141584, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 421/1000
# Loss: [array(5.3141584, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 422/1000
# Loss: [array(5.314158, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 423/1000
# Loss: [array(5.314158, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 424/1000
# Loss: [array(5.3141575, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 425/1000
# Loss: [array(5.3141575, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 426/1000
# Loss: [array(5.3141575, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 427/1000
# Loss: [array(5.314157, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 428/1000
# Loss: [array(5.314157, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 429/1000
# Loss: [array(5.3141565, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 430/1000
# Loss: [array(5.3141565, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 431/1000
# Loss: [array(5.314156, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 432/1000
# Loss: [array(5.314156, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 433/1000
# Loss: [array(5.3141556, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 434/1000
# Loss: [array(5.3141556, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 435/1000
# Loss: [array(5.314155, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 436/1000
# Loss: [array(5.314155, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 437/1000
# Loss: [array(5.314155, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 438/1000
# Loss: [array(5.3141546, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 439/1000
# Loss: [array(5.3141546, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 440/1000
# Loss: [array(5.314154, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 441/1000
# Loss: [array(5.314154, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 442/1000
# Loss: [array(5.3141537, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 443/1000
# Loss: [array(5.3141537, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 444/1000
# Loss: [array(5.314153, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 445/1000
# Loss: [array(5.314153, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 446/1000
# Loss: [array(5.314153, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 447/1000
# Loss: [array(5.3141527, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 448/1000
# Loss: [array(5.3141527, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 449/1000
# Loss: [array(5.3141522, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 450/1000
# Loss: [array(5.3141522, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 451/1000
# Loss: [array(5.314152, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 452/1000
# Loss: [array(5.314152, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 453/1000
# Loss: [array(5.314152, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 454/1000
# Loss: [array(5.3141513, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 455/1000
# Loss: [array(5.3141513, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 456/1000
# Loss: [array(5.314151, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 457/1000
# Loss: [array(5.314151, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 458/1000
# Loss: [array(5.314151, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 459/1000
# Loss: [array(5.3141503, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 460/1000
# Loss: [array(5.3141503, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 461/1000
# Loss: [array(5.31415, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 462/1000
# Loss: [array(5.31415, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 463/1000
# Loss: [array(5.31415, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 464/1000
# Loss: [array(5.3141494, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 465/1000
# Loss: [array(5.3141494, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 466/1000
# Loss: [array(5.314149, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 467/1000
# Loss: [array(5.314149, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 468/1000
# Loss: [array(5.314149, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 469/1000
# Loss: [array(5.3141484, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 470/1000
# Loss: [array(5.3141484, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 471/1000
# Loss: [array(5.3141484, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 472/1000
# Loss: [array(5.314148, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 473/1000
# Loss: [array(5.314148, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 474/1000
# Loss: [array(5.3141475, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 475/1000
# Loss: [array(5.3141475, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 476/1000
# Loss: [array(5.3141475, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 477/1000
# Loss: [array(5.314147, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 478/1000
# Loss: [array(5.314147, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 479/1000
# Loss: [array(5.314147, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 480/1000
# Loss: [array(5.3141465, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 481/1000
# Loss: [array(5.3141465, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 482/1000
# Loss: [array(5.314146, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 483/1000
# Loss: [array(5.314146, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 484/1000
# Loss: [array(5.314146, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 485/1000
# Loss: [array(5.3141456, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 486/1000
# Loss: [array(5.3141456, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 487/1000
# Loss: [array(5.3141456, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 488/1000
# Loss: [array(5.314145, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 489/1000
# Loss: [array(5.314145, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 490/1000
# Loss: [array(5.314145, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 491/1000
# Loss: [array(5.3141446, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 492/1000
# Loss: [array(5.3141446, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 493/1000
# Loss: [array(5.3141446, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 494/1000
# Loss: [array(5.314144, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 495/1000
# Loss: [array(5.314144, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 496/1000
# Loss: [array(5.3141437, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 497/1000
# Loss: [array(5.3141437, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 498/1000
# Loss: [array(5.3141437, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 499/1000
# Loss: [array(5.314143, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 500/1000
# Loss: [array(5.314143, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 501/1000
# Loss: [array(5.314143, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 502/1000
# Loss: [array(5.3141427, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 503/1000
# Loss: [array(5.3141427, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 504/1000
# Loss: [array(5.3141427, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 505/1000
# Loss: [array(5.314142, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 506/1000
# Loss: [array(5.314142, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 507/1000
# Loss: [array(5.314142, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 508/1000
# Loss: [array(5.3141418, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 509/1000
# Loss: [array(5.3141418, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 510/1000
# Loss: [array(5.3141418, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 511/1000
# Loss: [array(5.3141413, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 512/1000
# Loss: [array(5.3141413, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 513/1000
# Loss: [array(5.3141413, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 514/1000
# Loss: [array(5.314141, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 515/1000
# Loss: [array(5.314141, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 516/1000
# Loss: [array(5.314141, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 517/1000
# Loss: [array(5.314141, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 518/1000
# Loss: [array(5.3141403, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 519/1000
# Loss: [array(5.3141403, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 520/1000
# Loss: [array(5.3141403, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 521/1000
# Loss: [array(5.31414, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 522/1000
# Loss: [array(5.31414, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 523/1000
# Loss: [array(5.31414, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 524/1000
# Loss: [array(5.3141394, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 525/1000
# Loss: [array(5.3141394, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 526/1000
# Loss: [array(5.3141394, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 527/1000
# Loss: [array(5.314139, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 528/1000
# Loss: [array(5.314139, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 529/1000
# Loss: [array(5.314139, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 530/1000
# Loss: [array(5.314139, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 531/1000
# Loss: [array(5.3141384, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 532/1000
# Loss: [array(5.3141384, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 533/1000
# Loss: [array(5.3141384, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 534/1000
# Loss: [array(5.314138, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 535/1000
# Loss: [array(5.314138, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 536/1000
# Loss: [array(5.314138, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 537/1000
# Loss: [array(5.3141375, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 538/1000
# Loss: [array(5.3141375, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 539/1000
# Loss: [array(5.3141375, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 540/1000
# Loss: [array(5.3141375, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 541/1000
# Loss: [array(5.314137, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 542/1000
# Loss: [array(5.314137, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 543/1000
# Loss: [array(5.314137, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 544/1000
# Loss: [array(5.3141365, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 545/1000
# Loss: [array(5.3141365, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 546/1000
# Loss: [array(5.3141365, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 547/1000
# Loss: [array(5.3141365, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 548/1000
# Loss: [array(5.314136, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 549/1000
# Loss: [array(5.314136, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 550/1000
# Loss: [array(5.314136, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 551/1000
# ...
# Epoch 819/1000
# Loss: [array(5.3141117, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 820/1000
# Loss: [array(5.3141117, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 821/1000
# Loss: [array(5.3141117, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 822/1000
# Loss: [array(5.3141117, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 823/1000
# Loss: [array(5.3141117, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 824/1000
# Loss: [array(5.3141117, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 825/1000
# Loss: [array(5.3141117, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 826/1000
# Loss: [array(5.3141117, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 827/1000
# Loss: [array(5.3141117, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 828/1000
# Loss: [array(5.3141117, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 829/1000
# Loss: [array(5.3141117, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 830/1000
# Loss: [array(5.314111, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 831/1000
# Loss: [array(5.314111, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 832/1000
# Loss: [array(5.314111, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 833/1000
# Loss: [array(5.314111, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 834/1000
# Loss: [array(5.314111, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 835/1000
# Loss: [array(5.314111, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 836/1000
# Loss: [array(5.314111, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 837/1000
# Loss: [array(5.314111, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 838/1000
# Loss: [array(5.3141108, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 839/1000
# Loss: [array(5.3141108, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 840/1000
# Loss: [array(5.3141108, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 841/1000
# Loss: [array(5.3141108, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 842/1000
# Loss: [array(5.3141108, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 843/1000
# Loss: [array(5.3141108, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 844/1000
# Loss: [array(5.3141108, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 845/1000
# Loss: [array(5.3141108, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 846/1000
# Loss: [array(5.3141108, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 847/1000
# Loss: [array(5.3141103, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 848/1000
# Loss: [array(5.3141103, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 849/1000
# Loss: [array(5.3141103, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 850/1000
# Loss: [array(5.3141103, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 851/1000
# Loss: [array(5.3141103, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 852/1000
# Loss: [array(5.3141103, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 853/1000
# Loss: [array(5.3141103, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 854/1000
# Loss: [array(5.3141103, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 855/1000
# Loss: [array(5.31411, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 856/1000
# Loss: [array(5.31411, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 857/1000
# Loss: [array(5.31411, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 858/1000
# Loss: [array(5.31411, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 859/1000
# Loss: [array(5.31411, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 860/1000
# Loss: [array(5.31411, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 861/1000
# Loss: [array(5.31411, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 862/1000
# Loss: [array(5.31411, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 863/1000
# Loss: [array(5.31411, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 864/1000
# Loss: [array(5.3141093, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 865/1000
# Loss: [array(5.3141093, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 866/1000
# Loss: [array(5.3141093, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 867/1000
# Loss: [array(5.3141093, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 868/1000
# Loss: [array(5.3141093, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 869/1000
# Loss: [array(5.3141093, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 870/1000
# Loss: [array(5.3141093, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 871/1000
# Loss: [array(5.3141093, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 872/1000
# Loss: [array(5.3141093, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 873/1000
# Loss: [array(5.314109, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 874/1000
# Loss: [array(5.314109, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 875/1000
# Loss: [array(5.314109, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 876/1000
# Loss: [array(5.314109, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 877/1000
# Loss: [array(5.314109, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 878/1000
# Loss: [array(5.314109, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 879/1000
# Loss: [array(5.314109, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 880/1000
# Loss: [array(5.314109, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 881/1000
# Loss: [array(5.314109, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 882/1000
# Loss: [array(5.3141084, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 883/1000
# Loss: [array(5.3141084, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 884/1000
# Loss: [array(5.3141084, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 885/1000
# Loss: [array(5.3141084, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 886/1000
# Loss: [array(5.3141084, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 887/1000
# Loss: [array(5.3141084, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 888/1000
# Loss: [array(5.3141084, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 889/1000
# Loss: [array(5.3141084, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 890/1000
# Loss: [array(5.3141084, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 891/1000
# Loss: [array(5.314108, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 892/1000
# Loss: [array(5.314108, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 893/1000
# Loss: [array(5.314108, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 894/1000
# Loss: [array(5.314108, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 895/1000
# Loss: [array(5.314108, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 896/1000
# Loss: [array(5.314108, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 897/1000
# Loss: [array(5.314108, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 898/1000
# Loss: [array(5.314108, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 899/1000
# Loss: [array(5.314108, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 900/1000
# Loss: [array(5.3141074, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 901/1000
# Loss: [array(5.3141074, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 902/1000
# Loss: [array(5.3141074, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 903/1000
# Loss: [array(5.3141074, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 904/1000
# Loss: [array(5.3141074, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 905/1000
# Loss: [array(5.3141074, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 906/1000
# Loss: [array(5.3141074, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 907/1000
# Loss: [array(5.3141074, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 908/1000
# Loss: [array(5.3141074, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 909/1000
# Loss: [array(5.3141074, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 910/1000
# Loss: [array(5.314107, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 911/1000
# Loss: [array(5.314107, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 912/1000
# Loss: [array(5.314107, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 913/1000
# Loss: [array(5.314107, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 914/1000
# Loss: [array(5.314107, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 915/1000
# Loss: [array(5.314107, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 916/1000
# Loss: [array(5.314107, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 917/1000
# Loss: [array(5.314107, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 918/1000
# Loss: [array(5.314107, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 919/1000
# Loss: [array(5.314107, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 920/1000
# Loss: [array(5.3141065, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 921/1000
# Loss: [array(5.3141065, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 922/1000
# Loss: [array(5.3141065, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 923/1000
# Loss: [array(5.3141065, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 924/1000
# Loss: [array(5.3141065, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 925/1000
# Loss: [array(5.3141065, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 926/1000
# Loss: [array(5.3141065, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 927/1000
# Loss: [array(5.3141065, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 928/1000
# Loss: [array(5.3141065, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 929/1000
# Loss: [array(5.3141065, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 930/1000
# Loss: [array(5.314106, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 931/1000
# Loss: [array(5.314106, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 932/1000
# Loss: [array(5.314106, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 933/1000
# Loss: [array(5.314106, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 934/1000
# Loss: [array(5.314106, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 935/1000
# Loss: [array(5.314106, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 936/1000
# Loss: [array(5.314106, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 937/1000
# Loss: [array(5.314106, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 938/1000
# Loss: [array(5.314106, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 939/1000
# Loss: [array(5.314106, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 940/1000
# Loss: [array(5.3141055, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 941/1000
# Loss: [array(5.3141055, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 942/1000
# Loss: [array(5.3141055, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 943/1000
# Loss: [array(5.3141055, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 944/1000
# Loss: [array(5.3141055, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 945/1000
# Loss: [array(5.3141055, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 946/1000
# Loss: [array(5.3141055, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 947/1000
# Loss: [array(5.3141055, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 948/1000
# Loss: [array(5.3141055, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 949/1000
# Loss: [array(5.3141055, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 950/1000
# Loss: [array(5.314105, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 951/1000
# Loss: [array(5.314105, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 952/1000
# Loss: [array(5.314105, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 953/1000
# Loss: [array(5.314105, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 954/1000
# Loss: [array(5.314105, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 955/1000
# Loss: [array(5.314105, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 956/1000
# Loss: [array(5.314105, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 957/1000
# Loss: [array(5.314105, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 958/1000
# Loss: [array(5.314105, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 959/1000
# Loss: [array(5.314105, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 960/1000
# Loss: [array(5.314105, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 961/1000
# Loss: [array(5.3141046, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 962/1000
# Loss: [array(5.3141046, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 963/1000
# Loss: [array(5.3141046, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 964/1000
# Loss: [array(5.3141046, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 965/1000
# Loss: [array(5.3141046, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 966/1000
# Loss: [array(5.3141046, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 967/1000
# Loss: [array(5.3141046, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 968/1000
# Loss: [array(5.3141046, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 969/1000
# Loss: [array(5.3141046, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 970/1000
# Loss: [array(5.3141046, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 971/1000
# Loss: [array(5.3141046, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 972/1000
# Loss: [array(5.314104, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 973/1000
# Loss: [array(5.314104, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 974/1000
# Loss: [array(5.314104, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 975/1000
# Loss: [array(5.314104, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 976/1000
# Loss: [array(5.314104, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 977/1000
# Loss: [array(5.314104, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 978/1000
# Loss: [array(5.314104, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 979/1000
# Loss: [array(5.314104, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 980/1000
# Loss: [array(5.314104, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 981/1000
# Loss: [array(5.314104, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 982/1000
# Loss: [array(5.314104, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 983/1000
# Loss: [array(5.3141036, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 984/1000
# Loss: [array(5.3141036, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 985/1000
# Loss: [array(5.3141036, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 986/1000
# Loss: [array(5.3141036, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 987/1000
# Loss: [array(5.3141036, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 988/1000
# Loss: [array(5.3141036, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 989/1000
# Loss: [array(5.3141036, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 990/1000
# Loss: [array(5.3141036, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 991/1000
# Loss: [array(5.3141036, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 992/1000
# Loss: [array(5.3141036, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 993/1000
# Loss: [array(5.3141036, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 994/1000
# Loss: [array(5.3141036, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 995/1000
# Loss: [array(5.314103, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 996/1000
# Loss: [array(5.314103, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 997/1000
# Loss: [array(5.314103, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 998/1000
# Loss: [array(5.314103, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 999/1000
# Loss: [array(5.314103, dtype=float32), array(0.6666667, dtype=float32)]
# Epoch 1000/1000
# Loss: [array(5.314103, dtype=float32), array(0.6666667, dtype=float32)]
# Training complete.

# %%
import os
import numpy as np
import cv2
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import accuracy_score, precision_recall_fscore_support, roc_curve, auc, confusion_matrix

# Paths to test dataset
test_fire_path = "fire_detection_few_shot/test/Fire"
test_no_fire_path = "fire_detection_few_shot/test/No_Fire"

# Function to load and preprocess images
def load_and_preprocess_image(image_path, target_size=(224, 224)):
    img = cv2.imread(image_path)
    img = cv2.resize(img, target_size)
    img = img.astype("float32") / 255.0  # Normalize
    return img

# Load test images
fire_images = [os.path.join(test_fire_path, img) for img in os.listdir(test_fire_path)]
no_fire_images = [os.path.join(test_no_fire_path, img) for img in os.listdir(test_no_fire_path)]

# Create similar and dissimilar pairs
pairs = []
labels = []

for img1 in fire_images:
    for img2 in fire_images:
        if img1 != img2:
            pairs.append((img1, img2))
            labels.append(1)  # Similar (both fire)

for img1 in no_fire_images:
    for img2 in no_fire_images:
        if img1 != img2:
            pairs.append((img1, img2))
            labels.append(1)  # Similar (both no-fire)

for img1 in fire_images:
    for img2 in no_fire_images:
        pairs.append((img1, img2))
        labels.append(0)  # Dissimilar (fire vs no-fire)

# Convert to numpy arrays
X1 = np.array([load_and_preprocess_image(p[0]) for p in pairs])
X2 = np.array([load_and_preprocess_image(p[1]) for p in pairs])
labels = np.array(labels)

# Predict similarity scores
predictions = siamese_model.predict([X1, X2])
predictions = predictions.flatten()

# Choose a threshold (experiment with values)
threshold = 0.5
predicted_labels = (predictions >= threshold).astype(int)

# Compute evaluation metrics
accuracy = accuracy_score(labels, predicted_labels)
precision, recall, f1, _ = precision_recall_fscore_support(labels, predicted_labels, average="binary")

# ROC Curve and AUC
fpr, tpr, _ = roc_curve(labels, predictions)
roc_auc = auc(fpr, tpr)

# Print metrics
print(f"Accuracy: {accuracy:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"F1-score: {f1:.4f}")
# Out:
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 23s 1s/step
# Accuracy: 0.6429
# Precision: 0.6429
# Recall: 1.0000
# F1-score: 0.7826

# %%
# import numpy as np
# import tensorflow as tf
# from scipy.spatial import distance

# def get_embeddings(model, dataset):
#     """Extract embeddings for each image in the dataset using the Siamese encoder."""
#     embeddings = []
#     labels = []

#     for img, label in dataset:
#         emb = siamese_model.predict(tf.expand_dims(img, axis=0), verbose=0)
#         embeddings.append(emb[0])
#         labels.append(label.numpy())

#     return np.array(embeddings), np.array(labels)

# def find_hard_pairs(embeddings, labels, num_hard_pairs=500):
#     """Identify hard positive and hard negative pairs based on embeddings."""
#     positive_pairs = []
#     negative_pairs = []

#     for i in range(len(embeddings)):
#         for j in range(i + 1, len(embeddings)):
#             dist = distance.euclidean(embeddings[i], embeddings[j])  # Euclidean distance
#             same_label = labels[i] == labels[j]

#             if same_label:
#                 positive_pairs.append((dist, i, j))  # Store distance and indices
#             else:
#                 negative_pairs.append((dist, i, j))

#     # Sort pairs based on distance
#     positive_pairs.sort(reverse=True)  # Hard positives (should be close but are far)
#     negative_pairs.sort()  # Hard negatives (should be far but are close)

#     # Select top `num_hard_pairs`
#     hard_positive_pairs = [(embeddings[i], embeddings[j]) for _, i, j in positive_pairs[:num_hard_pairs]]
#     hard_negative_pairs = [(embeddings[i], embeddings[j]) for _, i, j in negative_pairs[:num_hard_pairs]]

#     return hard_positive_pairs, hard_negative_pairs

# %%
# def fine_tune_on_hard_pairs(siamese_model, hard_positive_pairs, hard_negative_pairs, epochs=5, batch_size=16):
#     """Train Siamese model on hard pairs for fine-tuning."""
#     hard_pairs = hard_positive_pairs + hard_negative_pairs
#     np.random.shuffle(hard_pairs)  # Shuffle the hard pairs

#     x1_train = np.array([pair[0] for pair in hard_pairs])
#     x2_train = np.array([pair[1] for pair in hard_pairs])
#     y_train = np.array([1] * len(hard_positive_pairs) + [0] * len(hard_negative_pairs))  # Labels

#     siamese_model.fit([x1_train, x2_train], y_train, batch_size=batch_size, epochs=epochs, verbose=1)

#     return siamese_model

# %%
for layer in siamese_model.layers:
    print(layer.name)
# Out:
# image_1_input
# image_2_input
# functional_2
# distance_layer_1
# dense_1

# %%
import tensorflow as tf

# Convert training pairs and labels into a TensorFlow dataset
training_dataset = tf.data.Dataset.from_tensor_slices((train_pair_data, train_pair_labels))

# Shuffle and batch the dataset
BATCH_SIZE = 16  # You can adjust this
training_dataset = training_dataset.shuffle(buffer_size=len(train_pair_data)).batch(BATCH_SIZE)

# Check dataset
print(training_dataset)
# Out:
# <_BatchDataset element_spec=(TensorSpec(shape=(None, 2, 224, 224, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int64, name=None))>

# %%
def split_pairs(pair, label):
    """Splits concatenated image pairs into two separate inputs."""
    if len(pair.shape) == 4:  # If pair has shape (2, 224, 224, 3)
        image_1 = pair[0, :, :, :]  # First image in the pair
        image_2 = pair[1, :, :, :]  # Second image in the pair
    elif len(pair.shape) == 5:  # If pair has shape (batch_size, 2, 224, 224, 3)
        image_1 = pair[:, 0, :, :, :]  # First image in batch
        image_2 = pair[:, 1, :, :, :]  # Second image in batch
    else:
        raise ValueError(f"Unexpected input shape: {pair.shape}")

    return image_1, image_2, label  # it returns 3 separate tensors

# %%
from sklearn.model_selection import train_test_split

# Define the validation split ratio
VAL_SPLIT = 0.2

# Splitting train_pair_data and train_pair_labels into training and validation sets
train_data, val_data, train_labels, val_labels = train_test_split(
    train_pair_data, train_pair_labels, test_size=VAL_SPLIT, random_state=42
)

# Converting training pairs and labels into a TensorFlow dataset
training_dataset = tf.data.Dataset.from_tensor_slices((train_data, train_labels))
training_dataset = training_dataset.map(split_pairs)

# Converting validation pairs and labels into a TensorFlow dataset
validation_dataset = tf.data.Dataset.from_tensor_slices((val_data, val_labels))
validation_dataset = validation_dataset.map(split_pairs)

# Shuffle and batch the training dataset
BATCH_SIZE = 16
training_dataset = training_dataset.shuffle(buffer_size=len(train_data)).batch(BATCH_SIZE)
validation_dataset = validation_dataset.batch(BATCH_SIZE)  # No need to shuffle the validation set

# Checking the structure of the training dataset
for batch in training_dataset.take(1):  # Taking one batch
    image_1, image_2, labels = batch
    print("Training Batch Shapes:")
    print("Image 1 shape:", image_1.shape)
    print("Image 2 shape:", image_2.shape)
    print("Labels shape:", labels.shape)

# Checking the structure of the validation dataset
for batch in validation_dataset.take(1):  # Taking one batch
    image_1, image_2, labels = batch
    print("\nValidation Batch Shapes:")
    print("Image 1 shape:", image_1.shape)
    print("Image 2 shape:", image_2.shape)
    print("Labels shape:", labels.shape)
# Out:
# Training Batch Shapes:
# Image 1 shape: (16, 224, 224, 3)
# Image 2 shape: (16, 224, 224, 3)
# Labels shape: (16,)
#
# Validation Batch Shapes:
# Image 1 shape: (16, 224, 224, 3)
# Image 2 shape: (16, 224, 224, 3)
# Labels shape: (16,)

# %%
import tensorflow as tf

initial_learning_rate = 1e-4
lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate, decay_steps=500, decay_rate=0.95, staircase=True
)

optimizer = tf.keras.optimizers.Adam(learning_rate=lr_schedule)
siamese_model.compile(optimizer=optimizer, loss='binary_crossentropy')

# %%
def contrastive_loss(y_true, y_pred):
    margin = 1.0
    return tf.reduce_mean(y_true * tf.square(y_pred) + (1 - y_true) * tf.square(tf.maximum(margin - y_pred, 0)))

siamese_model.compile(optimizer=optimizer, loss=contrastive_loss)

# %%
test_dataset = tf.data.Dataset.from_tensor_slices((test_pair_data, test_pair_labels))
test_dataset = test_dataset.map(split_pairs).batch(BATCH_SIZE)

# %%
siamese_model.fit(
    training_dataset.map(lambda img1, img2, lbl: ((img1, img2), lbl)),  # (input1, input2), labels
    epochs=20,
    validation_data=validation_dataset.map(lambda img1, img2, lbl: ((img1, img2), lbl)),
)
# Out:
# Epoch 1/20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 181s 3s/step - accuracy: 0.4916 - loss: 11200.0020 - val_accuracy: 0.5702 - val_loss: 3807.2407
# Epoch 2/20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 4s 143ms/step - accuracy: 0.4316 - loss: 5117.0171 - val_accuracy: 0.5702 - val_loss: 2493.4705
# Epoch 3/20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 4s 137ms/step - accuracy: 0.5018 - loss: 3315.7966 - val_accuracy: 0.5702 - val_loss: 2785.4939
# Epoch 4/20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 4s 133ms/step - accuracy: 0.4864 - loss: 1729.2338 - val_accuracy: 0.5702 - val_loss: 1251.0422
# Epoch 5/20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 5s 141ms/step - accuracy: 0.4639 - loss: 867.4349 - val_accuracy: 0.5702 - val_loss: 844.8386
# Epoch 6/20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 4s 136ms/step - accuracy: 0.4742 - loss: 519.3993 - val_accuracy: 0.5702 - val_loss: 468.4870
# Epoch 7/20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 5s 136ms/step - accuracy: 0.4980 - loss: 353.7663 - val_accuracy: 0.5702 - val_loss: 296.9236
# Epoch 8/20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 4s 143ms/step - accuracy: 0.4907 - loss: 244.5105 - val_accuracy: 0.5702 - val_loss: 200.1674
# Epoch 9/20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 4s 139ms/step - accuracy: 0.4970 - loss: 187.3179 - val_accuracy: 0.5702 - val_loss: 165.6819
# Epoch 10/20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 4s 138ms/step - accuracy: 0.4952 - loss: 144.8116 - val_accuracy: 0.5702 - val_loss: 139.0915
# Epoch 11/20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 5s 145ms/step - accuracy: 0.4699 - loss: 119.0273 - val_accuracy: 0.5702 - val_loss: 120.2428
# Epoch 12/20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 5s 137ms/step - accuracy: 0.5006 - loss: 101.8086 - val_accuracy: 0.5702 - val_loss: 102.0394
# Epoch 13/20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 4s 139ms/step - accuracy: 0.4524 - loss: 78.0803 - val_accuracy: 0.5702 - val_loss: 85.4390
# Epoch 14/20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 4s 143ms/step - accuracy: 0.4676 - loss: 72.1454 - val_accuracy: 0.5702 - val_loss: 72.2364
# Epoch 15/20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 4s 140ms/step - accuracy: 0.4880 - loss: 63.0782 - val_accuracy: 0.5702 - val_loss: 62.6555
# Epoch 16/20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 5s 141ms/step - accuracy: 0.4954 - loss: 60.3989 - val_accuracy: 0.5702 - val_loss: 54.2108
# Epoch 17/20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 4s 140ms/step - accuracy: 0.5213 - loss: 53.2533 - val_accuracy: 0.5702 - val_loss: 48.7863
# Epoch 18/20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 4s 140ms/step - accuracy: 0.4526 - loss: 42.5736 - val_accuracy: 0.5702 - val_loss: 44.2254
# Epoch 19/20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 5s 141ms/step - accuracy: 0.5499 - loss: 47.8521 - val_accuracy: 0.5702 - val_loss: 40.5383
# Epoch 20/20
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 5s 139ms/step - accuracy: 0.4707 - loss: 40.3146 - val_accuracy: 0.5702 - val_loss: 36.8461

# %%
import numpy as np
import tensorflow as tf
from sklearn.metrics import accuracy_score, confusion_matrix, precision_score, recall_score, f1_score

def evaluate_siamese_model(model, test_dataset):
    y_true = []
    y_pred = []

    # Iterate over test dataset
    for img1, img2, label in test_dataset:
        label = label.numpy().flatten()
        output = model.predict([img1, img2])  # Getting similarity scores
        predicted_similarity = output.flatten()

        y_true.extend(label)
        y_pred.extend(predicted_similarity)

    y_true = np.array(y_true, dtype=np.int32)
    y_pred = np.array(y_pred, dtype=np.float32)

    # Raw Predictions
    print("\n Sample Predictions (First 10):", y_pred[:10])
    print(" Min Prediction:", np.min(y_pred), "| Max Prediction:", np.max(y_pred))

    # Threshold Adjustment
    optimal_threshold = np.percentile(y_pred, 45)  # Median as threshold
    print(" Using Threshold:", optimal_threshold)

    y_pred_binary = (y_pred < optimal_threshold).astype(int)  # Converting distances to class labels

    # Calculate metrics
    accuracy = accuracy_score(y_true, y_pred_binary)
    precision = precision_score(y_true, y_pred_binary, zero_division=1)
    recall = recall_score(y_true, y_pred_binary, zero_division=1)
    f1 = f1_score(y_true, y_pred_binary, zero_division=1)

    # Print results
    print(f"\n Accuracy: {accuracy * 100:.2f}%")
    print(f" Precision: {precision:.2f}")
    print(f" Recall: {recall:.2f}")
    print(f" F1 Score: {f1:.2f}")
    print("\nConfusion Matrix:")
    print(confusion_matrix(y_true, y_pred_binary))

# Call the function
evaluate_siamese_model(siamese_model, test_dataset)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
#
#  Sample Predictions (First 10): [ 7.216183   5.921891   7.513638   5.9146037  8.211638   5.43777
#  12.810219   5.9750886  9.57534    4.858357 ]
#  Min Prediction: 4.858357 | Max Prediction: 14.792315
#  Using Threshold: 8.696918487548828
#
#  Accuracy: 82.50%
#  Precision: 0.88
#  Recall: 0.75
#  F1 Score: 0.81
#
# Confusion Matrix:
# [[18  2]
#  [ 5 15]]
